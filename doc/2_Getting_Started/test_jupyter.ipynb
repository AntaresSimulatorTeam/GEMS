# %% [markdown]
# This a JupyterNotebook

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

df = pd.read_csv('test_csv.csv')

print(df.head())
# Out:
#    solar   wind
# 0      0      1
# 1      0      2
# 2      2      3
# 3      0      2
# 4      0      0
